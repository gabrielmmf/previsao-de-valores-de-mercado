# %% [markdown]
# # Scraping de stats do fbref para todos os jogadores de todas as ligas
# Nesta seção serão obtidos os stats das top 5 ligas disponíveis no fbref.
#
# Como o fbref possui mais features a partir de 2017, foram criadas 2 pastas com os stats fbref:
# - 'data/new_fbref': contém stats a partir da temporada 2017, com informações extras, como xG
# - 'data/old_fbref': contém stats entre 2005 e 2016, com poucas informações e muitas infos faltantes, não prentendemos utilizar
#
# Os dataframes salvos em .csv possuem indexação de 1 nível, em vez do padrão, que seria multiindex
#
# Para cada tipo de stats, é criado um novo arquivo na pasta 'new_fbref' ou 'old_fbref'.
#     Ex: standard stats a partir de 2017: 'data/new_fbref/standard.csv'
#
# Têm os tipos abaixo:

# %%
import pandas as pd
pd.read_csv('data/new_fbref/standard.csv')
# Out:
#                    league  season     team                   player nation  \
# 0      ENG-Premier League    2017  Arsenal             Aaron Ramsey    WAL
# 1      ENG-Premier League    2017  Arsenal   Ainsley Maitland-Niles    ENG
# 2      ENG-Premier League    2017  Arsenal               Alex Iwobi    NGA
# 3      ENG-Premier League    2017  Arsenal  Alex Oxlade-Chamberlain    ENG
# 4      ENG-Premier League    2017  Arsenal      Alexandre Lacazette    FRA
# ...                   ...     ...      ...                      ...    ...
# 16706         ITA-Serie A    2022  Udinese             Sandi Lovrić    SVN
# 16707         ITA-Serie A    2022  Udinese           Simone Pafundi    ITA
# 16708         ITA-Serie A    2022  Udinese            Tolgay Arslan    GER
# 16709         ITA-Serie A    2022  Udinese           Vivaldo Semedo    POR
# 16710         ITA-Serie A    2022  Udinese                   Walace    BRA
#
#          pos   age    born  Playing Time_MP  Playing Time_Starts  ...  \
# 0         MF  26.0  1990.0               24                   21  ...
# 1      DF,MF  19.0  1997.0               15                    8  ...
# 2      MF,FW  21.0  1996.0               26                   22  ...
# 3         DF  23.0  1993.0                3                    3  ...
# 4         FW  26.0  1991.0               32                   26  ...
# ...      ...   ...     ...              ...                  ...  ...
# 16706     MF  24.0  1998.0               37                   28  ...
# 16707  MF,FW  16.0  2006.0                8                    0  ...
# 16708     MF  31.0  1990.0               36                   12  ...
# 16709  FW,MF  17.0  2005.0                5                    0  ...
# 16710     MF  27.0  1995.0               37                   37  ...
#
#        Per 90 Minutes_Ast  Per 90 Minutes_G+A  Per 90 Minutes_G-PK  \
# 0                    0.39                0.73                 0.34
# 1                    0.00                0.00                 0.00
# 2                    0.25                0.39                 0.15
# 3                    0.00                0.00                 0.00
# 4                    0.16                0.74                 0.49
# ...                   ...                 ...                  ...
# 16706                0.23                0.42                 0.19
# 16707                0.00                0.00                 0.00
# 16708                0.00                0.07                 0.07
# 16709                0.00                0.00                 0.00
# 16710                0.03                0.03                 0.00
#
#        Per 90 Minutes_G+A-PK  Per 90 Minutes_xG  Per 90 Minutes_xAG  \
# 0                       0.73               0.30                0.26
# 1                       0.00               0.02                0.08
# 2                       0.39               0.19                0.17
# 3                       0.00               0.09                0.19
# 4                       0.65               0.56                0.18
# ...                      ...                ...                 ...
# 16706                   0.42               0.18                0.12
# 16707                   0.00               0.09                0.16
# 16708                   0.07               0.16                0.12
# 16709                   0.00               0.25                0.00
# 16710                   0.03               0.03                0.05
#
#        Per 90 Minutes_xG+xAG  Per 90 Minutes_npxG  Per 90 Minutes_npxG+xAG  \
# 0                       0.56                 0.30                     0.56
# 1                       0.11                 0.02                     0.11
# 2                       0.36                 0.19                     0.36
# 3                       0.29                 0.09                     0.29
# 4                       0.74                 0.49                     0.67
# ...                      ...                  ...                      ...
# 16706                   0.31                 0.18                     0.31
# 16707                   0.25                 0.09                     0.25
# 16708                   0.29                 0.16                     0.29
# 16709                   0.25                 0.25                     0.25
# 16710                   0.08                 0.03                     0.08
#
#        nextSeason
# 0            2018
# 1            2018
# 2            2018
# 3            2018
# 4            2018
# ...           ...
# 16706        2023
# 16707        2023
# 16708        2023
# 16709        2023
# 16710        2023
#
# [16711 rows x 38 columns]

# %%
pd.read_csv('data/old_fbref/standard.csv')
# Out:
#                    league  season     team           player nation    pos  \
# 0      ENG-Premier League    2005  Arsenal       Abou Diaby    FRA     MF
# 1      ENG-Premier League    2005  Arsenal        Alex Song    CMR  DF,MF
# 2      ENG-Premier League    2005  Arsenal   Alexander Hleb    BLR     MF
# 3      ENG-Premier League    2005  Arsenal    Arturo Lupoli    ITA     FW
# 4      ENG-Premier League    2005  Arsenal      Ashley Cole    ENG     DF
# ...                   ...     ...      ...              ...    ...    ...
# 32413         ITA-Serie A    2016  Udinese    Silvan Widmer    SUI     DF
# 32414         ITA-Serie A    2016  Udinese   Simone Scuffet    ITA     GK
# 32415         ITA-Serie A    2016  Udinese     Stipe Perica    CRO  FW,MF
# 32416         ITA-Serie A    2016  Udinese        Sven Kums    BEL     MF
# 32417         ITA-Serie A    2016  Udinese  Thomas Heurtaux    FRA     DF
#
#         age    born  Playing Time_MP  Playing Time_Starts  ...  \
# 0      19.0  1986.0               12                    9  ...
# 1      17.0  1987.0                5                    3  ...
# 2      24.0  1981.0               25                   17  ...
# 3      18.0  1987.0                1                    0  ...
# 4      24.0  1980.0               11                    9  ...
# ...     ...     ...              ...                  ...  ...
# 32413  23.0  1993.0               28                   28  ...
# 32414  20.0  1996.0                6                    5  ...
# 32415  21.0  1995.0               27                    5  ...
# 32416  28.0  1988.0               29                   20  ...
# 32417  28.0  1988.0               12                    6  ...
#
#        Performance_PK  Performance_PKatt  Performance_CrdY  Performance_CrdR  \
# 0                 0.0                0.0                 2                 0
# 1                 0.0                0.0                 0                 0
# 2                 0.0                0.0                 0                 0
# 3                 0.0                0.0                 0                 0
# 4                 0.0                0.0                 3                 0
# ...               ...                ...               ...               ...
# 32413             0.0                0.0                 2                 0
# 32414             0.0                0.0                 0                 0
# 32415             0.0                0.0                 4                 0
# 32416             0.0                0.0                 3                 0
# 32417             0.0                0.0                 3                 0
#
#        Per 90 Minutes_Gls  Per 90 Minutes_Ast  Per 90 Minutes_G+A  \
# 0                    0.11                0.11                0.23
# 1                    0.00                0.00                0.00
# 2                    0.18                0.00                0.18
# 3                    0.00                0.00                0.00
# 4                    0.00                0.00                0.00
# ...                   ...                 ...                 ...
# 32413                0.00                0.14                0.14
# 32414                0.00                0.00                0.00
# 32415                0.50                0.08                0.58
# 32416                0.00                0.05                0.05
# 32417                0.00                0.17                0.17
#
#        Per 90 Minutes_G-PK  Per 90 Minutes_G+A-PK  nextSeason
# 0                     0.11                   0.23        2006
# 1                     0.00                   0.00        2006
# 2                     0.18                   0.18        2006
# 3                     0.00                   0.00        2006
# 4                     0.00                   0.00        2006
# ...                    ...                    ...         ...
# 32413                 0.00                   0.14        2017
# 32414                 0.00                   0.00        2017
# 32415                 0.50                   0.58        2017
# 32416                 0.00                   0.05        2017
# 32417                 0.00                   0.17        2017
#
# [32418 rows x 26 columns]

# %%
import soccerdata as sd
from tqdm import tqdm
# Out:
# [07/03/23 15:52:12] INFO     No custom team name replacements found. You can configure these in       ]8;id=873776;file:///home/gabrielmmf/anaconda3/envs/env1/lib/python3.9/site-packages/soccerdata/_config.py\_config.py]8;;\:]8;id=226515;file:///home/gabrielmmf/anaconda3/envs/env1/lib/python3.9/site-packages/soccerdata/_config.py#85\85]8;;\
#                              /home/gabrielmmf/soccerdata/config/teamname_replacements.json.
#                     INFO     No custom league dict found. You can configure additional leagues in    ]8;id=478199;file:///home/gabrielmmf/anaconda3/envs/env1/lib/python3.9/site-packages/soccerdata/_config.py\_config.py]8;;\:]8;id=764185;file:///home/gabrielmmf/anaconda3/envs/env1/lib/python3.9/site-packages/soccerdata/_config.py#159\159]8;;\
#                              /home/gabrielmmf/soccerdata/config/league_dict.json.

# %%
stats_types = ["standard", "shooting", "passing", "passing_types", "goal_shot_creation", "defense", "possession", "playing_time", "keeper", "misc"]

# %%
old_seasons = ["05-06", "06-07", "07-08", "08-09","09-10", "10-11", "11-12", "12-13", "13-14", "14-15", "15-16", "16-17"]
new_seasons = ["17-18", "18-19", "19-20","20-21", "21-22", "22-23"]

old_fbref = sd.FBref(leagues="Big 5 European Leagues Combined", seasons=old_seasons)
new_fbref = sd.FBref(leagues="Big 5 European Leagues Combined", seasons=new_seasons)
# Out:
#                     INFO     Saving cached data to /home/gabrielmmf/soccerdata/data/FBref             ]8;id=61792;file:///home/gabrielmmf/anaconda3/envs/env1/lib/python3.9/site-packages/soccerdata/_common.py\_common.py]8;;\:]8;id=349569;file:///home/gabrielmmf/anaconda3/envs/env1/lib/python3.9/site-packages/soccerdata/_common.py#89\89]8;;\
#                     INFO     Saving cached data to /home/gabrielmmf/soccerdata/data/FBref             ]8;id=541887;file:///home/gabrielmmf/anaconda3/envs/env1/lib/python3.9/site-packages/soccerdata/_common.py\_common.py]8;;\:]8;id=717361;file:///home/gabrielmmf/anaconda3/envs/env1/lib/python3.9/site-packages/soccerdata/_common.py#89\89]8;;\

# %%
def reindex(df):
    df = df.reset_index()
    multiindex = df.columns
    index = ['_'.join(level) if level[1] != '' else level[0]
             for level in multiindex]

    df = df.set_axis(index, axis=1)
    year_mapping = {
        "0304": "2003",
        "0405": "2004",
        "0506": "2005",
        "0607": "2006",
        "0708": "2007",
        "0809": "2008",
        "0910": "2009",
        "1011": "2010",
        "1112": "2011",
        "1213": "2012",
        "1314": "2013",
        "1415": "2014",
        "1516": "2015",
        "1617": "2016",
        "1718": "2017",
        "1819": "2018",
        "1920": "2019",
        "2021": "2020",
        "2122": "2021",
        "2223": "2022"
    }

    next_year_mapping = {
        "2003": "2004",
        "2004": "2005",
        "2005": "2006",
        "2006": "2007",
        "2007": "2008",
        "2008": "2009",
        "2009": "2010",
        "2010": "2011",
        "2011": "2012",
        "2012": "2013",
        "2013": "2014",
        "2014": "2015",
        "2015": "2016",
        "2016": "2017",
        "2017": "2018",
        "2018": "2019",
        "2019": "2020",
        "2020": "2021",
        "2021": "2022",
        "2022": "2023"
    }
    df["season"] = df["season"].replace(year_mapping)
    df["nextSeason"] = df["season"].replace(next_year_mapping)

    df['season'] = df['season'].astype('int')
    df['nextSeason'] = df['nextSeason'].astype('int')
    return df

# %%
for type in tqdm(stats_types, total=len(stats_types)):
    reindex(new_fbref.read_player_season_stats(stat_type=type)).to_csv('data/new_fbref/' + type + '.csv', index=False)
    reindex(old_fbref.read_player_season_stats(stat_type=type)).to_csv('data/old_fbref/' + type + '.csv', index=False)
# Out:
# 100%|██████████| 1/1 [01:35<00:00, 95.47s/it]
